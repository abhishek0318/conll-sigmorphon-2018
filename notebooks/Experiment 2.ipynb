# %% [markdown]
# # Simple Attention over characters and tags (Kann et. Shutze)

# %%
START_CHAR = '⏵'
STOP_CHAR = '⏹'
UNKNOWN_CHAR = '⊗'
UNKNOWN_TAG = '⊤'
PAD_CHAR = '₮'
PAD_TAG = '<PAD>'

# %%
# %matplotlib inline

from itertools import zip_longest
import os
import pickle
import time

import Levenshtein
import numpy as np
from sklearn.model_selection import train_test_split
from matplotlib.font_manager import FontProperties
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence
import torch.nn.functional as F

# %%
def load_data(file_name):
    """Loads data.

    Args:
        file_name: path to file containing the data

    Returns:
        lemmas: list of lemma
        tags: list of tags
        inflected_forms: list of inflected form
    """

    with open(file_name, 'r', encoding='utf') as file:
        text = file.read()

    lemmas = []
    tags = []
    inflected_forms = []

    for line in text.split('\n')[:-1]:
        lemma, inflected_form, tag = line.split('\t')
        lemmas.append(lemma)
        inflected_forms.append(inflected_form)
        tags.append(tag) 

    return lemmas, tags, inflected_forms

def get_index_dictionaries(lemmas, tags, inflected_forms):
    """Returns char2index, index2char, tag2index

    Args:
        lemmas: list of lemma
        tags: list of tags
        inflected_forms: list of inflected form

    Returns: 
        char2index: a dictionary which maps character to index
        index2char: a dictionary which maps index to character
        tag2index: a ditionary which maps morphological tag to index 
    """

    unique_chars = set(''.join(lemmas) + ''.join(inflected_forms))
    unique_chars.update(START_CHAR, STOP_CHAR) # special start and end symbols
    unique_chars.update(UNKNOWN_CHAR) # special charcter for unknown word
    char2index = {}
    index2char = {}

    char2index[PAD_CHAR] = 0
    index2char[0] = PAD_CHAR
    
    for index, char in enumerate(unique_chars):
        char2index[char] = index + 1
        index2char[index + 1] = char

    unique_tags = set(';'.join(tags).split(';'))
    unique_tags.update(UNKNOWN_TAG)
    tag2index = {tag:index+1 for index, tag in enumerate(unique_tags)}
    tag2index[PAD_TAG] = 0

    return char2index, index2char, tag2index

def get_combined_index_dictionaries(lemmas, tags, inflected_forms):
    """Returns char2index, index2char

    Args:
        lemmas: list of lemma
        tags: list of tags
        inflected_forms: list of inflected form

    Returns: 
        char2index: a dictionary which maps inputs and  to index
        index2char: a dictionary which maps index to inputs
    """

    unique_chars = set(''.join(lemmas) + ''.join(inflected_forms))
    unique_chars.update(START_CHAR, STOP_CHAR, UNKNOWN_CHAR) # special start and end symbols  
    
    input2index = {}
    index2input = {}
    
    input2index[PAD_CHAR] = 0
    index2input[0] = PAD_CHAR
        
    for index, char in enumerate(unique_chars, start=1):
        input2index[char] = index
        index2input[index] = char
        
    char_vocab_length = len(input2index.keys())

    unique_tags = set(';'.join(tags).split(';'))
    unique_tags.add(UNKNOWN_TAG) # special character for unknown tags
    
    for index, char in enumerate(unique_tags, start=char_vocab_length):
        input2index[char] = index
        index2input[index] = char

    return input2index, index2input, char_vocab_length

def words_to_indices(words, char2index, tensor=False, start_char=False, stop_char=False):
    """Converts list of words to a list with list containing indices

    Args:
        words: list of words
        char2index: dictionary which maps character to index
        tensor: if to return a list of tensor  

    Returns:
        tensor: list of list/tensor containing indices for a sequence of characters
    """

    list_indices = []
    for word in words:
        word_indices = []
        if start_char:
            word_indices.append(char2index[START_CHAR])
        for char in word:
            if char in char2index.keys():
                word_indices.append(char2index[char])
            else:
                word_indices.append(char2index[UNKNOWN_CHAR])
        if stop_char:
            word_indices.append(char2index[STOP_CHAR])
        if tensor:
            word_indices = torch.Tensor(word_indices)
        list_indices.append(word_indices)

    return list_indices

def tag_to_vector(tags, tag2index):
    """Returns one hot representation of tags given a tag.

    Args:
        tags: list of string representation of tag (eg, V;IND;PRS;2;PL)

    Returns:
        tag_vectors: list of 1D tensors with one hot representation of tags 
    """

    tag_vectors = []
    for tag in tags:
        tag_vector = torch.zeros(len(tag2index))
        for tag_feature in tag.split(';'):
            if tag_feature in tag2index:
                tag_vector[tag2index[tag_feature]] = 1
            else:
                tag_vector[tag2index[UNKNOWN_TAG]] = 1
        tag_vectors.append(tag_vector)
    return tag_vectors

def tag_to_indices(tags, tag2index):
    """Converts list of tags to a list of lists containing indices

    Args:
        words: list of tags

    Returns:
        tensor: list of list containing indices of sub_tags
    """
    
    list_indices = []
    for tag in tags:
        tag_indices = []
        for sub_tag in tag.split(';'):
            if sub_tag in tag2index.keys():
                tag_indices.append(tag2index[sub_tag])
            else:
                tag_indices.append(tag2index[UNKNOWN_TAG])
        list_indices.append(tag_indices)

    return list_indices
    

def indices_to_word(indices, index2char):
    """Returns a word given list contaning indices of words

    Args:
        indices: list containing indices

    Returns:
        word: a string
    """

    return ''.join([index2char[index] for index in indices])[:-1]

def pad_lists(lists, pad_int, pad_len=None):
    """Pads lists in a list to make them of equal size"""
    
    if pad_len is None:
        pad_len = max([len(lst) for lst in lists])
    new_list = []
    for lst in lists:
        if len(lst) < pad_len:
            new_list.append(torch.tensor(lst + [pad_int] * (pad_len-len(lst))))
        else:
            new_list.append(torch.tensor(lst[:pad_len]))
    return torch.stack(new_list)

def merge_lists(lists1, lists2):
    """Add two list of lists."""
    
    merged_lists = []
    for list1, list2 in zip(lists1, lists2):
        merged_lists.append(list1 + list2)
    return merged_lists

def grouper(iterable, n, fillvalue=None):
    "Collect data into fixed-length chunks or blocks"
    # grouper('ABCDEFG', 3, 'x') --> ABC DEF Gxx"
    args = [iter(iterable)] * n
    return zip_longest(*args, fillvalue=fillvalue)

def accuracy(predictions, targets):
    correct_count = 0
    for prediction, target in zip(predictions, targets):
        if prediction == target:
            correct_count += 1
    return correct_count / len(predictions)

def average_distance(predictions, targets):
    total_distance = 0
    for prediction, target in zip(predictions, targets):
        total_distance += Levenshtein.distance(prediction, target)
    return total_distance / len(predictions)

def evaluate(predictions, targets):
    return accuracy(predictions, targets), average_distance(predictions, targets)

# %%
language = 'middle-french'
dataset = 'high'

# %%
lemmas, tags, inflected_forms = load_data('./conll2018/task1/all/{}-train-{}'.format(language, dataset))

# %%
lemmas_train, lemmas_val, tags_train, tags_val, inflected_forms_train, inflected_forms_val = train_test_split(lemmas, tags, inflected_forms, test_size=0.2, random_state=42)

# %%
input2index, index2input, char_vocab_size = get_combined_index_dictionaries(lemmas_train, tags_train, inflected_forms_train)

# %% [markdown]
# # Train

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
batch_size = 32
embedding_size = 300
hidden_size = 100
input_vocab_size = len(index2input.keys())

# %% [markdown]
#     class Attention(nn.Module):
#         def __init__(self, hidden_size):
#             # Custom
#
#             super(Attention, self).__init__()
#             self.linear = nn.Linear(3*hidden_size, 1)
#
#         def forward(self, encoded_input, hidden_state, input_mask):
#             src_len = encoded_input.shape[1]
#             concat = torch.cat([encoded_input, hidden_state.transpose(0, 1).expand(-1, src_len, -1)], dim=2)
#             attn_weights = F.tanh(self.linear(concat).squeeze())
#
#             input_mask = input_mask.float()
#             input_mask = torch.where(input_mask == 0, torch.zeros_like(input_mask), torch.ones_like(input_mask) * float('inf'))
#             attn_weights = attn_weights - input_mask
#             # attn_weights.data.masked_fill_(input_mask, float('-inf'))
#
#             attn_weights = F.softmax(attn_weights, dim=1)
#             return attn_weights

# %% [markdown]
#     class Attention(nn.Module):
#         def __init__(self, hidden_size, intermediate_size=100):
#             # concat scoring function - global attention
#             # https://arxiv.org/pdf/1508.04025.pdf
#
#             super(Attention, self).__init__()
#             if intermediate_size is None:
#                 intermediate_size = int(attention_input_size ** (1/2))
#             self.W_a = nn.Linear(3*hidden_size, intermediate_size, bias=False)
#             self.v_a = nn.Linear(intermediate_size, 1, bias=False)
#
#         def forward(self, encoded_input, hidden_state, input_mask):
#             src_len = encoded_input.shape[1]
#             concat = torch.cat([encoded_input, hidden_state.transpose(0, 1).expand(-1, src_len, -1)], dim=2)
#             attn_weights = F.tanh(self.W_a(concat))
#             attn_weights = self.v_a(attn_weights).squeeze()
#             attn_weights.data.masked_fill_(input_mask, float('-inf'))
#             attn_weights = F.softmax(attn_weights, dim=1)
#             return attn_weights

# %%
class Attention(nn.Module):
    def __init__(self, hidden_size, p=0.3):
        # general scoring function - global attention 
        # https://arxiv.org/pdf/1508.04025.pdf

        super(Attention, self).__init__()
        self.W_a = nn.Linear(2*hidden_size, hidden_size, bias=False)
        # self.dropout = nn.Dropout(p)

    def forward(self, encoded_input, hidden_state, input_mask):
        src_len = encoded_input.shape[1]
        attn_weights = torch.bmm(self.W_a(encoded_input), hidden_state.transpose(0, 1).transpose(1, 2)).squeeze()
        attn_weights.data.masked_fill_(input_mask, float('-inf'))
        # attn_weights = dropout(attn_weights)
        attn_weights = F.softmax(attn_weights, dim=1)
        return attn_weights

# %% [markdown]
#     class Attention(nn.Module):
#         def __init__(self, attention_input_size, intermediate_size=100):
#             super(Attention, self).__init__()
#
#         def forward(self, encoded_input, hidden_state, input_mask):
#             src_len = encoded_input.shape[1]
#             attn_weights = (encoded_input * torch.cat([hidden_state.transpose(0, 1).expand(-1, src_len, -1), hidden_state.transpose(0, 1).expand(-1, src_len, -1)], dim=2)).sum(dim=2)
#
#             input_mask = input_mask.float()
#             input_mask = torch.where(input_mask == 0, torch.zeros_like(input_mask), torch.ones_like(input_mask) * float('inf'))
#             attn_weights = attn_weights - input_mask
#             #attn_weights.masked_fill_(input_mask, float('-inf'))
#
#             attn_weights = F.softmax(attn_weights, dim=1)
#             return attn_weights

# %%
Embedder = nn.Embedding(input_vocab_size, embedding_size, padding_idx=input2index[PAD_CHAR]).to(device)
Encoder = nn.LSTM(embedding_size, hidden_size, batch_first=True, bidirectional=True).to(device)
attention = Attention(hidden_size).to(device)
Decoder = nn.LSTM(embedding_size + 2 * hidden_size, hidden_size, batch_first=True).to(device)
linear1 = nn.Linear(3 * hidden_size, char_vocab_size - 1, ).to(device) # remove pad character option
dropout1 = torch.nn.Dropout(p=0)
log_softmax = nn.LogSoftmax(dim=2).to(device)
criterion = nn.NLLLoss(ignore_index=-1)
params = list(Embedder.parameters()) + list(Encoder.parameters()) + list(Decoder.parameters()) + list(linear1.parameters())+ list(attention.parameters())

# %%
def test(lemmas_val, tags_val, inflected_forms_val, batch_size=32, attn_debug=False, max_pred_len=25):

    inflected_predicted = []
    inflected_forms_true = []
    if attn_debug:
        input_seq = []
        attn_weights_all = []
    output_indices = []

    for batch in grouper(zip(lemmas_val, tags_val, inflected_forms_val), batch_size):
        batch = list(filter(lambda x: x is not None, batch))
        lemmas, tags, inflected_forms = zip(*batch)

        lemmas_indices = words_to_indices(lemmas, input2index, start_char=True, stop_char=True)
        tags_indices = tag_to_indices(tags, input2index)    
        input_indices = merge_lists(lemmas_indices, tags_indices)

        # Sort by length of input sequence
        input_indices, inflected_forms = zip(*sorted(zip(input_indices, inflected_forms), key=lambda x: len(x[0]), reverse=True))        
        if attn_debug:
            input_seq += [[index2input[index] for index in input_indices1] for input_indices1 in input_indices]
        input_indices = [torch.tensor(lst) for lst in input_indices]

        input_tensor = pad_sequence(input_indices, padding_value=input2index[PAD_CHAR], batch_first=True).to(device)
        embedding = Embedder(input_tensor)
        lengths = [Tensor.shape[0] for Tensor in input_indices]
        packed_input = pack_padded_sequence(embedding, lengths, batch_first=True)
        encoded_packed_seq, (hidden, cell) = Encoder(packed_input)
        encoded_input = pad_packed_sequence(encoded_packed_seq, batch_first=True)[0]
        
        input_mask = input_tensor == 0
        # input_mask = torch.where(input_mask > 0, torch.zeros_like(input_mask), torch.ones_like(input_mask) * float('inf')) 


        # Decode
        hidden_state = hidden[0,:,:] + hidden[1,:,:]
        hidden_state = hidden_state.unsqueeze(0)
        cell_state = torch.zeros(1, len(lengths), hidden_size).to(device)

        decoder_input = torch.tensor([input2index[START_CHAR]] * len(lengths)).to(device)
        decoder_input = Embedder(decoder_input).unsqueeze(1)


        outputs = []
        attn_weights_sequence = []
        for seq in range(0, max_pred_len):
            attn_weights = attention(encoded_input, hidden_state, input_mask)
            if attn_debug:
                attn_weights_sequence.append(attn_weights)
            context = torch.bmm(attn_weights.unsqueeze(1), encoded_input).squeeze()

            decoder_input_concat = torch.cat([context.unsqueeze(1), decoder_input], dim=2)

            output, (hidden_state, cell_state) = Decoder(decoder_input_concat, (hidden_state, cell_state))
            output = F.relu(linear1(torch.cat([hidden_state, context.unsqueeze(0)], dim=2)))            
            decoder_input = Embedder(output.argmax(dim=2) + 1).transpose(0, 1)
            outputs.append(output.squeeze())

        if attn_debug:
            attn_weights_sequence = torch.stack(attn_weights_sequence, dim=1)
            attn_weights_all.append(attn_weights_sequence)
        output_indices.append(torch.stack(outputs).argmax(dim=2))
        inflected_forms_true += inflected_forms

    output_indices = torch.cat(output_indices, dim=1).transpose(0, 1).cpu().numpy()
    for indices in output_indices:
        inflected_predicted.append(''.join([index2input[index + 1] for index in indices]).split(STOP_CHAR)[0])
            
    if attn_debug:
        max_src_len = max([x.shape[2] for x in attn_weights_all])
        for i in range(len(attn_weights_all)):
            attn_weights = attn_weights_all[i]
            batch_size = attn_weights.shape[0]
            src_len = attn_weights.shape[2]
            attn_weights_all[i] = torch.zeros(batch_size, max_pred_len, max_src_len)
            attn_weights_all[i][:,:,:src_len] = attn_weights
        attn_weights_all = torch.cat(attn_weights_all, dim=0)
        return inflected_predicted, input_seq, attn_weights_all
    else:
        return inflected_predicted, inflected_forms_true

# %%
optimiser = optim.Adagrad(params, lr=0.1)

# %%
def train(lemmas_train, tags_train, inflected_forms_train, epochs=1):
    start_time = time.time()

    for epoch in range(epochs):

        epoch_loss = 0

        for batch in grouper(zip(lemmas_train, tags_train, inflected_forms_train), batch_size):
            batch = list(filter(lambda x: x is not None, batch))
            lemmas, tags, inflected_forms = zip(*batch)


            lemmas_indices = words_to_indices(lemmas, input2index, start_char=True, stop_char=True)
            tags_indices = tag_to_indices(tags, input2index)    
            inflected_forms_indices = words_to_indices(inflected_forms, input2index)
            input_indices = merge_lists(lemmas_indices, tags_indices)

            # Sort by length of input sequence
            input_indices, inflected_forms_indices = zip(*sorted(zip(input_indices, inflected_forms_indices), key=lambda x: len(x[0]), reverse=True))
            input_indices = [torch.tensor(lst) for lst in input_indices]

            optimiser.zero_grad()

            input_tensor = pad_sequence(input_indices, padding_value=input2index[PAD_CHAR], batch_first=True).to(device)
            embedding = Embedder(input_tensor)
            lengths = [Tensor.shape[0] for Tensor in input_indices]
            packed_input = pack_padded_sequence(embedding, lengths, batch_first=True)
            encoded_packed_seq, (hidden, cell) = Encoder(packed_input)
            encoded_input = pad_packed_sequence(encoded_packed_seq, batch_first=True)[0]
            
            input_mask = input_tensor == 0
            # input_mask = torch.where(input_mask > 0, torch.zeros_like(input_mask), torch.ones_like(input_mask) * float('inf')) 

            # Decode
            hidden_state = hidden[0,:,:] + hidden[1,:,:]
            hidden_state = hidden_state.unsqueeze(0)
            cell_state = torch.zeros(1, len(lengths), hidden_size).to(device)

            target = pad_lists([lst + [input2index[STOP_CHAR]] for lst in inflected_forms_indices], input2index[PAD_CHAR]).to(device)    
            target = target - 1

            decoder_input = pad_lists(inflected_forms_indices, input2index[PAD_CHAR]).to(device)
            decoder_input = torch.cat([torch.tensor([input2index[START_CHAR]] * len(lengths)).unsqueeze(1).to(device), decoder_input], dim=1)
            decoder_input = Embedder(decoder_input)

            loss = 0

            max_length = target.shape[1]
            for seq in range(0, max_length):
                attn_weights = attention(encoded_input, hidden_state, input_mask)
                context = torch.bmm(attn_weights.unsqueeze(1), encoded_input).squeeze()
                
                decoder_input_concat = torch.cat([context.unsqueeze(1), decoder_input[:,seq,:].unsqueeze(1)], dim=2)
                
                output, (hidden_state, cell_state) = Decoder(decoder_input_concat, (hidden_state, cell_state))
                output = F.relu(linear1(torch.cat([hidden_state, context.unsqueeze(0)], dim=2)))
                output = dropout1(output)
                output = log_softmax(output).squeeze()
                loss += criterion(output, target[:,seq])

            epoch_loss += loss.item()
            loss.backward()
            optimiser.step()

        print("Epoch: {}/{}\tTime: {:.2f}s\tLoss: {:.4f}\tAccuracy: {:.4f}\tDistance: {:.4f} ".format(epoch+1, epochs, time.time() - start_time, epoch_loss / len(lemmas_train), *evaluate(*test(lemmas_val, tags_val, inflected_forms_val))))

# %%
train(lemmas_train, tags_train, inflected_forms_train, epochs=70)
# Out:
# Epoch: 1/70	Time: 4.62s	Loss: 0.7700	Accuracy: 0.0005	Distance: 5.9980
# Epoch: 2/70	Time: 9.91s	Loss: 0.4469	Accuracy: 0.0490	Distance: 4.2135
# Epoch: 3/70	Time: 15.25s	Loss: 0.3241	Accuracy: 0.1285	Distance: 3.2225
# Epoch: 4/70	Time: 20.61s	Loss: 0.2449	Accuracy: 0.2080	Distance: 2.7650
# Epoch: 5/70	Time: 25.95s	Loss: 0.1957	Accuracy: 0.2670	Distance: 2.5140
# Epoch: 6/70	Time: 31.32s	Loss: 0.1736	Accuracy: 0.3430	Distance: 2.3195
# Epoch: 7/70	Time: 36.73s	Loss: 0.1574	Accuracy: 0.3155	Distance: 2.3275
# Epoch: 8/70	Time: 42.08s	Loss: 0.1510	Accuracy: 0.3630	Distance: 2.1700
# Epoch: 9/70	Time: 47.42s	Loss: 0.1388	Accuracy: 0.4435	Distance: 1.7110
# Epoch: 10/70	Time: 52.89s	Loss: 0.1115	Accuracy: 0.4785	Distance: 1.6175
# Epoch: 11/70	Time: 58.25s	Loss: 0.1021	Accuracy: 0.5415	Distance: 1.4110
# Epoch: 12/70	Time: 63.62s	Loss: 0.0965	Accuracy: 0.5310	Distance: 1.4245
# Epoch: 13/70	Time: 68.99s	Loss: 0.0857	Accuracy: 0.5905	Distance: 1.2510
# Epoch: 14/70	Time: 74.35s	Loss: 0.0776	Accuracy: 0.5995	Distance: 1.2140
# Epoch: 15/70	Time: 79.72s	Loss: 0.0701	Accuracy: 0.6280	Distance: 1.1325
# Epoch: 16/70	Time: 85.07s	Loss: 0.0769	Accuracy: 0.6160	Distance: 1.1615
# Epoch: 17/70	Time: 90.43s	Loss: 0.0707	Accuracy: 0.6300	Distance: 1.1540
# Epoch: 18/70	Time: 95.80s	Loss: 0.0661	Accuracy: 0.6620	Distance: 1.0365
# Epoch: 19/70	Time: 101.24s	Loss: 0.0597	Accuracy: 0.6655	Distance: 1.0395
# Epoch: 20/70	Time: 106.77s	Loss: 0.0564	Accuracy: 0.6830	Distance: 0.9705
# Epoch: 21/70	Time: 112.16s	Loss: 0.0529	Accuracy: 0.6885	Distance: 0.9380
# Epoch: 22/70	Time: 117.55s	Loss: 0.0513	Accuracy: 0.6985	Distance: 0.8940
# Epoch: 23/70	Time: 122.92s	Loss: 0.0515	Accuracy: 0.7055	Distance: 0.9025
# Epoch: 24/70	Time: 128.33s	Loss: 0.0522	Accuracy: 0.6605	Distance: 1.0450
# Epoch: 25/70	Time: 133.69s	Loss: 0.0511	Accuracy: 0.7010	Distance: 0.8975
# Epoch: 26/70	Time: 139.06s	Loss: 0.0482	Accuracy: 0.6895	Distance: 0.9485
# Epoch: 27/70	Time: 144.45s	Loss: 0.0468	Accuracy: 0.7145	Distance: 0.8805
# Epoch: 28/70	Time: 149.83s	Loss: 0.0456	Accuracy: 0.6650	Distance: 0.9555
# Epoch: 29/70	Time: 155.21s	Loss: 0.0401	Accuracy: 0.8145	Distance: 0.5170
# Epoch: 30/70	Time: 160.63s	Loss: 0.0296	Accuracy: 0.8225	Distance: 0.4700
# Epoch: 31/70	Time: 166.00s	Loss: 0.0275	Accuracy: 0.8270	Distance: 0.4675
# Epoch: 32/70	Time: 171.39s	Loss: 0.0269	Accuracy: 0.8310	Distance: 0.4770
# Epoch: 33/70	Time: 177.07s	Loss: 0.0265	Accuracy: 0.8415	Distance: 0.4385
# Epoch: 34/70	Time: 182.59s	Loss: 0.0272	Accuracy: 0.8335	Distance: 0.4820
# Epoch: 35/70	Time: 188.09s	Loss: 0.0259	Accuracy: 0.8385	Distance: 0.4565
# Epoch: 36/70	Time: 193.59s	Loss: 0.0283	Accuracy: 0.7910	Distance: 0.5590
# Epoch: 37/70	Time: 199.15s	Loss: 0.0361	Accuracy: 0.7975	Distance: 0.5565
# Epoch: 38/70	Time: 204.76s	Loss: 0.0372	Accuracy: 0.7485	Distance: 0.6700
# Epoch: 39/70	Time: 210.28s	Loss: 0.0760	Accuracy: 0.6770	Distance: 0.8745
# Epoch: 40/70	Time: 215.75s	Loss: 0.0536	Accuracy: 0.7595	Distance: 0.6745
# Epoch: 41/70	Time: 221.14s	Loss: 0.0498	Accuracy: 0.7740	Distance: 0.6350
# Epoch: 42/70	Time: 226.51s	Loss: 0.0399	Accuracy: 0.7975	Distance: 0.5875
# Epoch: 43/70	Time: 231.89s	Loss: 0.0402	Accuracy: 0.7740	Distance: 0.6730
# Epoch: 44/70	Time: 237.27s	Loss: 0.0506	Accuracy: 0.7440	Distance: 0.6880
# Epoch: 45/70	Time: 242.65s	Loss: 0.0407	Accuracy: 0.8060	Distance: 0.5230
# Epoch: 46/70	Time: 248.03s	Loss: 0.0344	Accuracy: 0.8100	Distance: 0.5340
# Epoch: 47/70	Time: 253.46s	Loss: 0.0306	Accuracy: 0.8235	Distance: 0.5055
# Epoch: 48/70	Time: 258.86s	Loss: 0.0286	Accuracy: 0.8225	Distance: 0.5420
# Epoch: 49/70	Time: 264.25s	Loss: 0.0275	Accuracy: 0.8440	Distance: 0.4335
# Epoch: 50/70	Time: 269.64s	Loss: 0.0254	Accuracy: 0.8490	Distance: 0.4240
# Epoch: 51/70	Time: 275.03s	Loss: 0.0241	Accuracy: 0.8555	Distance: 0.4065
# Epoch: 52/70	Time: 280.43s	Loss: 0.0234	Accuracy: 0.8570	Distance: 0.4195
# Epoch: 53/70	Time: 285.82s	Loss: 0.0227	Accuracy: 0.8575	Distance: 0.4030
# Epoch: 54/70	Time: 291.22s	Loss: 0.0222	Accuracy: 0.8615	Distance: 0.4095
# Epoch: 55/70	Time: 296.62s	Loss: 0.0221	Accuracy: 0.8580	Distance: 0.4185
# Epoch: 56/70	Time: 302.00s	Loss: 0.0229	Accuracy: 0.8600	Distance: 0.4080
# Epoch: 57/70	Time: 307.37s	Loss: 0.0227	Accuracy: 0.8600	Distance: 0.4000
# Epoch: 58/70	Time: 312.74s	Loss: 0.0241	Accuracy: 0.8565	Distance: 0.4285
# Epoch: 59/70	Time: 318.13s	Loss: 0.0249	Accuracy: 0.8155	Distance: 0.5530
# Epoch: 60/70	Time: 323.53s	Loss: 0.0253	Accuracy: 0.8535	Distance: 0.4170
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-abfe754c2155> in <module>()
# ----> 1 train(lemmas_train, tags_train, inflected_forms_train, epochs=70)
#
# <ipython-input-14-9d88fc481910> in train(lemmas_train, tags_train, inflected_forms_train, epochs)
#      60
#      61             epoch_loss += loss.item()
# ---> 62             loss.backward()
#      63             optimiser.step()
#      64
#
# ~/anaconda3/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#      91                 products. Defaults to ``False``.
#      92         """
# ---> 93         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#      94
#      95     def register_hook(self, hook):
#
# ~/anaconda3/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      87     Variable._execution_engine.run_backward(
#      88         tensors, grad_tensors, retain_graph, create_graph,
# ---> 89         allow_unreachable=True)  # allow_unreachable flag
#      90
#      91
#
# KeyboardInterrupt:

# %%
print("Train accuracy:", evaluate(*test(lemmas_train, tags_train, inflected_forms_train)), "Validation accuracy: ", evaluate(*test(lemmas_val, tags_val, inflected_forms_val)))
# Out:
# Train accuracy: (0.899875, 0.291125) Validation accuracy:  (0.856, 0.4305)

# %%
optimiser = optim.Adagrad(params, lr=0.01)

# %%
train(lemmas_train, tags_train, inflected_forms_train, epochs=30)
# Out:
# Epoch: 1/30	Time: 4.72s	Loss: 0.0320	Accuracy: 0.8520	Distance: 0.4255
# Epoch: 2/30	Time: 10.11s	Loss: 0.0235	Accuracy: 0.8575	Distance: 0.4125
# Epoch: 3/30	Time: 15.51s	Loss: 0.0214	Accuracy: 0.8650	Distance: 0.3860
# Epoch: 4/30	Time: 20.92s	Loss: 0.0207	Accuracy: 0.8625	Distance: 0.4095
# Epoch: 5/30	Time: 26.33s	Loss: 0.0200	Accuracy: 0.8650	Distance: 0.4095
# Epoch: 6/30	Time: 31.73s	Loss: 0.0195	Accuracy: 0.8665	Distance: 0.4125
# Epoch: 7/30	Time: 37.12s	Loss: 0.0191	Accuracy: 0.8680	Distance: 0.4060
# Epoch: 8/30	Time: 42.53s	Loss: 0.0188	Accuracy: 0.8705	Distance: 0.4000
# Epoch: 9/30	Time: 47.98s	Loss: 0.0186	Accuracy: 0.8700	Distance: 0.3900
# Epoch: 10/30	Time: 53.45s	Loss: 0.0184	Accuracy: 0.8715	Distance: 0.3895
# Epoch: 11/30	Time: 58.82s	Loss: 0.0181	Accuracy: 0.8725	Distance: 0.3810
# Epoch: 12/30	Time: 64.18s	Loss: 0.0178	Accuracy: 0.8735	Distance: 0.3815
# Epoch: 13/30	Time: 69.56s	Loss: 0.0177	Accuracy: 0.8745	Distance: 0.3785
# Epoch: 14/30	Time: 74.92s	Loss: 0.0176	Accuracy: 0.8730	Distance: 0.3730
# Epoch: 15/30	Time: 80.31s	Loss: 0.0205	Accuracy: 0.8660	Distance: 0.3970
# Epoch: 16/30	Time: 85.75s	Loss: 0.0179	Accuracy: 0.8720	Distance: 0.3815
# Epoch: 17/30	Time: 91.22s	Loss: 0.0175	Accuracy: 0.8775	Distance: 0.3600
# Epoch: 18/30	Time: 96.63s	Loss: 0.0174	Accuracy: 0.8755	Distance: 0.3595
# Epoch: 19/30	Time: 102.04s	Loss: 0.0172	Accuracy: 0.8760	Distance: 0.3730
# Epoch: 20/30	Time: 107.46s	Loss: 0.0171	Accuracy: 0.8760	Distance: 0.3770
# Epoch: 21/30	Time: 113.00s	Loss: 0.0169	Accuracy: 0.8760	Distance: 0.3805
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-a3f72fb2f252> in <module>()
# ----> 1 train(lemmas_train, tags_train, inflected_forms_train, epochs=30)
#
# <ipython-input-14-9d88fc481910> in train(lemmas_train, tags_train, inflected_forms_train, epochs)
#      60
#      61             epoch_loss += loss.item()
# ---> 62             loss.backward()
#      63             optimiser.step()
#      64
#
# ~/anaconda3/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#      91                 products. Defaults to ``False``.
#      92         """
# ---> 93         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#      94
#      95     def register_hook(self, hook):
#
# ~/anaconda3/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      87     Variable._execution_engine.run_backward(
#      88         tensors, grad_tensors, retain_graph, create_graph,
# ---> 89         allow_unreachable=True)  # allow_unreachable flag
#      90
#      91
#
# KeyboardInterrupt:

# %%
print("Train accuracy:", evaluate(*test(lemmas_train, tags_train, inflected_forms_train)), "Validation accuracy: ", evaluate(*test(lemmas_val, tags_val, inflected_forms_val)))
# Out:
# Train accuracy: (0.923375, 0.24) Validation accuracy:  (0.8745, 0.3735)

# %% [markdown]
# # Visualising

# %%
pred, input_seq, attn_weights = test(lemmas_val[:100], tags_val[:100], inflected_forms_val[:100], batch_size=32, attn_debug=True)

# %%
def showAttention(input_sentence, output_words, attentions, font=None):
    # https://pytorch.org/tutorials/intermediate/seq2seq_translation_tutorial.html
        
    # Set up figure with colorbar
    fig = plt.figure(figsize=(15,15))
    ax = fig.add_subplot(111)
    cax = ax.matshow(attentions, cmap='bone')
    fig.colorbar(cax)

    # Set up axes
    font = FontProperties(fname=font, size=24)
    ax.set_xticklabels([''] + input_sentence, rotation=90, fontproperties=font)
    ax.set_yticklabels([''] + output_words, fontproperties=font)
    ax.tick_params(axis='both', which='major', pad=15)

    # Show label at every tick
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

    plt.show()

# %%
i = 8
print('X: axis:', ', '.join(list(input_seq[i])))
print('Y: axis:', ', '.join(list(pred[i])), pred[i])
showAttention(input_seq[i], list(pred[i]), attn_weights[i, :len(pred[i])].cpu().detach().numpy(), 'Nirmala.ttf')
# Out:
# X: axis: ⏵, p, r, a, e, p, a, r, e, r, ⏹, V, 1, SG, COND, LGSPEC2
# Y: axis: p, r, a, e, p, a, r, e, r, o, y, s praepareroys

# %%
#list(zip(*test(lemmas_val, tags_val, inflected_forms_val)))

# %% [markdown]
# # Development Dataset

# %%
lemmas_dev, tags_dev, inflected_forms_dev = load_data('./conll2018/task1/all/{}-dev'.format(language))

# %%
evaluate(*test(lemmas_dev, tags_dev, inflected_forms_dev))
# Out:
# (0.886, 0.308)

# %% [markdown]
# Hindi/high - (0.747, 1.191)
# Middle-French/high - (0.886, 0.308)

# %%
for prediction, truth in zip(*test(lemmas_dev, tags_dev, inflected_forms_dev)):
    print("Prediction: {}\tTruth: {}".format(prediction, truth))
# Out:
# Prediction: enconvenencierois	Truth: enconvenencierois
# Prediction: pourpensiez	Truth: pourpensiez
# Prediction: accompaignerez	Truth: accompaignerez
# Prediction: allaictois	Truth: allaictois
# Prediction: adioustoyent	Truth: adioustoyent
# Prediction: menassoys	Truth: menassoys
# Prediction: pourforce	Truth: pourforce
# Prediction: approuchie	Truth: approuche
# Prediction: effectuas	Truth: effectuas
# Prediction: evaporiez	Truth: evaporiez
# Prediction: besoigneroient	Truth: besoigneroient
# Prediction: desista	Truth: desista
# Prediction: baptisastes	Truth: baptisastes
# Prediction: essayoys	Truth: essayoys
# Prediction: afferma	Truth: afferma
# Prediction: armoie	Truth: armoia
# Prediction: essilieroys	Truth: essilieroys
# Prediction: exploreriez	Truth: exploreriez
# Prediction: aornois	Truth: aornois
# Prediction: esperassiez	Truth: esperassiez
# Prediction: evityez	Truth: evityez
# Prediction: gaigna	Truth: gaigna
# Prediction: eslancent	Truth: eslancent
# Prediction: baysassions	Truth: baysassions
# Prediction: desyrent	Truth: desyrent
# Prediction: estimerions	Truth: estimerions
# Prediction: affieront	Truth: affieront
# Prediction: mesleroient	Truth: mesleroient
# Prediction: resveroyt	Truth: resveroyt
# Prediction: oublye	Truth: oublye
# Prediction: cryes	Truth: cryes
# Prediction: enlant	Truth: en deslyant
# Prediction: esgratignasse	Truth: esgratignasse
# Prediction: accomplissoyt	Truth: accomplissoyy
# Prediction: entitulyez	Truth: entitulyez
# Prediction: allaictyez	Truth: allaictyez
# Prediction: gouvernyons	Truth: gouvernyons
# Prediction: enchargeassent	Truth: enchargeassent
# Prediction: accointyez	Truth: accointyez
# Prediction: eschaufferiez	Truth: eschaufferiez
# Prediction: troussois	Truth: troussois
# Prediction: inquietons	Truth: inquietons
# Prediction: souspirera	Truth: souspirera
# Prediction: esbauchons	Truth: esbauchons
# Prediction: esquachent	Truth: esquachent
# Prediction: esguisa	Truth: esguisa
# Prediction: tournoyeriez	Truth: tournoyeriez
# Prediction: tournastes	Truth: tournastes
# Prediction: supposeroit	Truth: supposeroit
# Prediction: cherchent	Truth: cherchent
# Prediction: apatissoyent	Truth: apatissoyent
# Prediction: huchastes	Truth: huchastes
# Prediction: empiegeons	Truth: empiegeons
# Prediction: desirera	Truth: desirera
# Prediction: reiettez	Truth: reiettez
# Prediction: leschera	Truth: leschera
# Prediction: capa	Truth: capa
# Prediction: songent	Truth: songent
# Prediction: dancent	Truth: dancent
# Prediction: affions	Truth: affions
# Prediction: retire	Truth: retire
# Prediction: iecteriez	Truth: iecteriez
# Prediction: rouiller	Truth: rouiller
# Prediction: cryeryons	Truth: cryeryons
# Prediction: conseilloient	Truth: conseilloient
# Prediction: practicquent	Truth: practicquent
# Prediction: redoubtoys	Truth: redoubtoys
# Prediction: renouvellent	Truth: renouvellent
# Prediction: blasperent	Truth: blasphement
# Prediction: destablassent	Truth: destablassent
# Prediction: intoxiqueroys	Truth: intoxiqueroys
# Prediction: souspire	Truth: souspire
# Prediction: despencerois	Truth: despencerois
# Prediction: prosperez	Truth: prospererez
# Prediction: enterrerai	Truth: enterrerai
# Prediction: gaimenteroyent	Truth: gaimenteroyent
# Prediction: obligerent	Truth: obligerent
# Prediction: delacent	Truth: delacent
# Prediction: dancroyent	Truth: dançoyent
# Prediction: reiecteroys	Truth: reiecteroys
# Prediction: desistez	Truth: desistez
# Prediction: gousteray	Truth: gousteray
# Prediction: toucherent	Truth: toucherent
# Prediction: embouchez	Truth: embouchez
# Prediction: ivuidyons	Truth: vuidyons
# Prediction: habiterons	Truth: habiterons
# Prediction: accuserions	Truth: accuserions
# Prediction: aioyent	Truth: avoyent
# Prediction: fiancera	Truth: fiancera
# Prediction: mascheroit	Truth: mascheroit
# Prediction: embausmé	Truth: embausmé
# Prediction: aerasmes	Truth: aerasmes
# Prediction: fluirois	Truth: fluirois
# Prediction: moustrer	Truth: moustrer
# Prediction: evitez	Truth: evitez
# Prediction: tocquer	Truth: toquer
# Prediction: descouchierions	Truth: descouchierions
# Prediction: esternuoyent	Truth: esternuoyent
# Prediction: enpoisonnerois	Truth: enpoisonnerois
# Prediction: conseilla	Truth: conseilla
# Prediction: enchargeast	Truth: enchargeast
# Prediction: reiectoys	Truth: reiectoys
# Prediction: recullassiez	Truth: recullassiez
# Prediction: penetrasses	Truth: penetrasses
# Prediction: desheritons	Truth: desheritons
# Prediction: quereleriez	Truth: quereleriez
# Prediction: seuroleras	Truth: quereleras
# Prediction: declairons	Truth: declairons
# Prediction: honnourons	Truth: honnourons
# Prediction: tocont	Truth: toquoyent
# Prediction: coucha	Truth: coucha
# Prediction: desploie	Truth: desploie
# Prediction: empirasmes	Truth: empirasmes
# Prediction: habitassiez	Truth: habitassiez
# Prediction: prepareroys	Truth: prepareroys
# Prediction: achapterois	Truth: achapterois
# Prediction: escorche	Truth: escorche
# Prediction: invitas	Truth: invitas
# Prediction: nombres	Truth: nombres
# Prediction: ausoyt	Truth: ausoyt
# Prediction: qisieriez	Truth: visiteriez
# Prediction: aguyserions	Truth: aguyserions
# Prediction: apuyons	Truth: apuyons
# Prediction: rinceryons	Truth: rinceryons
# Prediction: disnons	Truth: disnons
# Prediction: retyrez	Truth: retyrez
# Prediction: gardons	Truth: gardons
# Prediction: dervé	Truth: dervé
# Prediction: traveilloit	Truth: traveilloit
# Prediction: contregarderions	Truth: contregarderions
# Prediction: escouilloit	Truth: escouilloit
# Prediction: courouchierent	Truth: courouchierent
# Prediction: asseuroys	Truth: asseuroys
# Prediction: empescherai	Truth: empescherai
# Prediction: resignoit	Truth: resignoit
# Prediction: mortifieront	Truth: mortifieront
# Prediction: confermeriez	Truth: confermeriez
# Prediction: accomplierois	Truth: accomplirois
# Prediction: honnoureront	Truth: honnoureront
# Prediction: commencons	Truth: commençons
# Prediction: giella	Truth: veigla
# Prediction: exploreroyent	Truth: exploreroyent
# Prediction: lurryez	Truth: lurryez
# Prediction: aguysassent	Truth: aguysassent
# Prediction: cachoys	Truth: cachoys
# Prediction: fianceryons	Truth: fianceryons
# Prediction: escumez	Truth: escumez
# Prediction: mercyent	Truth: mercyent
# Prediction: revereriez	Truth: revereriez
# Prediction: redrechié	Truth: redrechié
# Prediction: temprerons	Truth: temprerons
# Prediction: avallons	Truth: avallons
# Prediction: urinent	Truth: urinent
# Prediction: tourois	Truth: toques
# Prediction: ruyneryons	Truth: ruyneryons
# Prediction: pecherois	Truth: pecherois
# Prediction: marions	Truth: marions
# Prediction: macterois	Truth: macterois
# Prediction: pryent	Truth: pryent
# Prediction: branslé	Truth: branslé
# Prediction: interpretassions	Truth: interpretassions
# Prediction: accompaigneroient	Truth: accompaigneroient
# Prediction: desbauchoys	Truth: desbauchoys
# Prediction: deschargeas	Truth: deschargeas
# Prediction: demonstra	Truth: demonstra
# Prediction: esveiglois	Truth: esveiglois
# Prediction: regrettoyt	Truth: regrettoyt
# Prediction: enchargeoys	Truth: enchargeoys
# Prediction: detranchent	Truth: detranchent
# Prediction: demonstrons	Truth: demonstrons
# Prediction: delibererent	Truth: delibererent
# Prediction: preferas	Truth: preferas
# Prediction: quereleray	Truth: quereleray
# Prediction: gaignyons	Truth: gaignyons
# Prediction: estimois	Truth: estimois
# Prediction: arachyons	Truth: arachyons
# Prediction: destachons	Truth: destachons
# Prediction: gaignassions	Truth: gaignassions
# Prediction: invadasse	Truth: invadasse
# Prediction: doubta	Truth: doubta
# Prediction: emblas	Truth: emblas
# Prediction: escrieryons	Truth: escrieryons
# Prediction: logeasses	Truth: logeasses
# Prediction: habite	Truth: habite
# Prediction: escouiller	Truth: escouiller
# Prediction: evites	Truth: evites
# Prediction: aymerai	Truth: aymerai
# Prediction: cuydes	Truth: cuydes
# Prediction: leve	Truth: leve
# Prediction: notons	Truth: notons
# Prediction: ertusant	Truth: en troussant
# Prediction: ale	Truth: va
# Prediction: courrouches	Truth: courrouches
# Prediction: courrouchiez	Truth: courrouchiez
# Prediction: alimentoit	Truth: alimentoit
# Prediction: espoventeryez	Truth: espoventeryez
# Prediction: ordonnoit	Truth: ordonnoit
# Prediction: pourforces	Truth: pourforces
# Prediction: tranchyons	Truth: tranchyons
# Prediction: embausma	Truth: embausma
# Prediction: empensoys	Truth: empensoys
# Prediction: tesmoignerons	Truth: tesmoignerons
# Prediction: racompteroyent	Truth: racompteroyent
# Prediction: espousasses	Truth: espousasses
# Prediction: edifioys	Truth: edifioys
# Prediction: acoustre	Truth: acoustre
# Prediction: desployeriez	Truth: desployeriez
# Prediction: soumectez	Truth: soumectez
# Prediction: serainerois	Truth: serainerois
# Prediction: enferrez	Truth: enferrez
# Prediction: moustrent	Truth: moustrent
# Prediction: deliberons	Truth: deliberons
# Prediction: avanchons	Truth: avanchions
# Prediction: estiquions	Truth: estiquions
# Prediction: enconiecturant	Truth: en coniecturant
# Prediction: tramperont	Truth: tramperont
# Prediction: estime	Truth: estime
# Prediction: affies	Truth: affies
# Prediction: fluisse	Truth: fluisse
# Prediction: abayons	Truth: abayons
# Prediction: alosez	Truth: alosez
# Prediction: escapper	Truth: escapper
# Prediction: aymez	Truth: aymez
# Prediction: cryent	Truth: cryons
# Prediction: enconvenencoys	Truth: enconvenençoys
# Prediction: entrefrappiyons	Truth: entrefrappyons
# Prediction: entrefismes	Truth: entrefismes
# Prediction: declairoyt	Truth: declairoyt
# Prediction: racointa	Truth: racointa
# Prediction: remonstreroit	Truth: remonstreroit
# Prediction: possessessessessessessess	Truth: possesses
# Prediction: acoustumez	Truth: acoustumez
# Prediction: laidengent	Truth: laidengent
# Prediction: iniuriasses	Truth: iniuriasses
# Prediction: racomptent	Truth: racomptent
# Prediction: reietterai	Truth: reietterai
# Prediction: esleveray	Truth: esleveray
# Prediction: pissiez	Truth: pissiez
# Prediction: heilez	Truth: heilyez
# Prediction: estudieroit	Truth: estudieroit
# Prediction: ployions	Truth: ployions
# Prediction: pillyons	Truth: pillyons
# Prediction: protegeriez	Truth: protegeriez
# Prediction: levoient	Truth: levoient
# Prediction: faisoys	Truth: faisoys
# Prediction: ausois	Truth: ausois
# Prediction: alterons	Truth: alterons
# Prediction: resumes	Truth: resumes
# Prediction: quitteront	Truth: quitteront
# Prediction: esvertuant	Truth: en esvertuant
# Prediction: dilatons	Truth: dilatons
# Prediction: lurrez	Truth: lurrez
# Prediction: faisses	Truth: faces
# Prediction: celeroys	Truth: celeroys
# Prediction: fluirions	Truth: fluirions
# Prediction: enqueter	Truth: jecter
# Prediction: desposses	Truth: despossessa
# Prediction: traveilloyt	Truth: traveilloyt
# Prediction: abandonnoyent	Truth: abandonnoyent
# Prediction: descourage	Truth: descourage
# Prediction: embouchois	Truth: embouchois
# Prediction: acceptoient	Truth: acceptoient
# Prediction: cauterieroys	Truth: cauterizeroys
# Prediction: expuysiez	Truth: expuysiez
# Prediction: rappelleray	Truth: rappelleray
# Prediction: estonnyez	Truth: estonnyez
# Prediction: deschaineryons	Truth: deschaineryons
# Prediction: souspirassiez	Truth: souspirassiez
# Prediction: tremblerai	Truth: tremblerai
# Prediction: redoubterez	Truth: redoubterez
# Prediction: gaignoyent	Truth: gaignoyent
# Prediction: tocquyois	Truth: tocquions
# Prediction: entitulent	Truth: entitulent
# Prediction: gaimente	Truth: gaimente
# Prediction: heiliyons	Truth: heilyons
# Prediction: renommeroys	Truth: renommeroys
# Prediction: gastoient	Truth: gastoient
# Prediction: renomme	Truth: renomme
# Prediction: moderons	Truth: moderons
# Prediction: exposons	Truth: exposons
# Prediction: estimeroyt	Truth: estimeroyt
# Prediction: espierent	Truth: espierent
# Prediction: edifieryons	Truth: edifieryons
# Prediction: escryeroys	Truth: escryeroys
# Prediction: esgale	Truth: esgale
# Prediction: lurrons	Truth: lurrons
# Prediction: assister	Truth: assister
# Prediction: huaiastes	Truth: huastes
# Prediction: contrepoisasmes	Truth: contrepoisasmes
# Prediction: accompaigneryons	Truth: accompaigneryons
# Prediction: presupposerai	Truth: presupposerai
# Prediction: empoique	Truth: empoizonne
# Prediction: traittoient	Truth: traittoient
# Prediction: travaillastes	Truth: travaillastes
# Prediction: empoiquerions	Truth: empoizonnerions
# Prediction: desregliez	Truth: desregliez
# Prediction: accomplierai	Truth: accomplirai
# Prediction: enseigne	Truth: enseigne
# Prediction: presentassiez	Truth: presentassiez
# Prediction: plaidoyt	Truth: plaidoyt
# Prediction: flattoys	Truth: flattoys
# Prediction: plaidyons	Truth: plaidyons
# Prediction: inquieterions	Truth: inquieterions
# Prediction: raportent	Truth: raportent
# Prediction: encommencer	Truth: encommencer
# Prediction: enterreroys	Truth: enterreroys
# Prediction: protegeryons	Truth: protegeryons
# Prediction: esparpiller	Truth: esparpiller
# Prediction: frapoisions	Truth: frapions
# Prediction: ottroyeront	Truth: ottroyeront
# Prediction: desnoue	Truth: desnoue
# Prediction: saultez	Truth: saultez
# Prediction: tramperoient	Truth: tramperoient
# Prediction: souppes	Truth: souppes
# Prediction: toqua	Truth: toqua
# Prediction: danceroit	Truth: danceroit
# Prediction: ostassent	Truth: ostassent
# Prediction: nommeryez	Truth: nommeryez
# Prediction: menassant	Truth: menassant
# Prediction: empiegeant	Truth: empiegeant
# Prediction: contregardas	Truth: contregardas
# Prediction: desconseille	Truth: desconseille
# Prediction: estincellasses	Truth: estincellasses
# Prediction: encommences	Truth: encommences
# Prediction: detranchiez	Truth: detranchiez
# Prediction: conquestassiez	Truth: conquestassiez
# Prediction: empeschassiez	Truth: empeschassiez
# Prediction: courrouces	Truth: courrouces
# Prediction: soulaigeassiez	Truth: soulaigeassiez
# Prediction: hebergeas	Truth: hebergeas
# Prediction: cabassasses	Truth: cabassasses
# Prediction: amadoua	Truth: amadoua
# Prediction: arrengierois	Truth: arrengierois
# Prediction: respirasmes	Truth: respirasmes
# Prediction: possederiez	Truth: possederiez
# Prediction: monstreroyt	Truth: monstreroyt
# Prediction: pretiez	Truth: pretiez
# Prediction: accorderoient	Truth: accorderoient
# Prediction: separ	Truth: separerai
# Prediction: pastures	Truth: pastures
# Prediction: couchasses	Truth: couchasses
# Prediction: laschasses	Truth: laschasses
# Prediction: esventes	Truth: esventes
# Prediction: espereroys	Truth: espereroys
# Prediction: lasches	Truth: lasches
# Prediction: retireryez	Truth: retireryez
# Prediction: portas	Truth: portas
# Prediction: qoulez	Truth: vollez
# Prediction: enistrant	Truth: en desistant
# Prediction: tempré	Truth: tempré
# Prediction: hachant	Truth: hachant
# Prediction: aier	Truth: avoyr
# Prediction: soubhaitteray	Truth: soubhaitteray
# Prediction: redrechois	Truth: redrechois
# Prediction: renouvellasse	Truth: renouvellasse
# Prediction: nousyerez	Truth: vous entreruynerez
# Prediction: resigniez	Truth: resigniez
# Prediction: suffoccuoys	Truth: suffocquerois
# Prediction: mehaigne	Truth: mehaigne
# Prediction: grieois	Truth: quereloys
# Prediction: desroutas	Truth: desroutas
# Prediction: praesenteryez	Truth: praesenteryez
# Prediction: remonstres	Truth: remonstres
# Prediction: desguisast	Truth: desguisast
# Prediction: estiquieroient	Truth: estiquieroient
# Prediction: subiecteroient	Truth: subiecteroient
# Prediction: fleschioyt	Truth: fleschissoyy
# Prediction: chocquassions	Truth: chocquassions
# Prediction: encontreras	Truth: encontreras
# Prediction: monstrez	Truth: monstrez
# Prediction: bransleryez	Truth: bransleryez
# Prediction: cuydoys	Truth: cuydoys
# Prediction: desloge	Truth: desloge
# Prediction: employeroys	Truth: employeroys
# Prediction: riffleryons	Truth: riffleryons
# Prediction: cryoit	Truth: cryoit
# Prediction: arriveryez	Truth: arriveryez
# Prediction: pecheront	Truth: pecheront
# Prediction: espieroyent	Truth: espieroyent
# Prediction: desplacer	Truth: desplacer
# Prediction: tuastes	Truth: tuastes
# Prediction: preferé	Truth: preferé
# Prediction: cabassé	Truth: cabassé
# Prediction: payeroyt	Truth: payeroyt
# Prediction: contrepoisiez	Truth: contrepoisiez
# Prediction: entrencontrez	Truth: entrencontrez vous
# Prediction: desguisoient	Truth: desguisoient
# Prediction: pourpensasmes	Truth: pourpensasmes
# Prediction: fourageoys	Truth: fourageoys
# Prediction: soubhaitteroys	Truth: soubhaitteroys
# Prediction: exstirpois	Truth: exstirpois
# Prediction: encommencerions	Truth: encommencerions
# Prediction: praesidyons	Truth: praesidyons
# Prediction: enhortois	Truth: enhortois
# Prediction: intoxiquerez	Truth: intoxiquerez
# Prediction: conquesterions	Truth: conquesterions
# Prediction: soucyoyent	Truth: soucyoyent
# Prediction: cerchieray	Truth: cerchieray
# Prediction: revencheroient	Truth: revencheroient
# Prediction: trompiyons	Truth: trompyons
# Prediction: esvertuera	Truth: esvertuera
# Prediction: moderasmes	Truth: moderasmes
# Prediction: enclineroyent	Truth: enclineroyent
# Prediction: nommyez	Truth: nommyez
# Prediction: sceusions	Truth: sçavions
# Prediction: demeslez	Truth: demeslez
# Prediction: chargent	Truth: chargent
# Prediction: enyvrons	Truth: enyvrons
# Prediction: guiderai	Truth: guiderai
# Prediction: engrions	Truth: vengions
# Prediction: mettroient	Truth: mettrons
# Prediction: dancera	Truth: dancera
# Prediction: hucherois	Truth: hucherois
# Prediction: ruyneroyt	Truth: ruyneroyt
# Prediction: pryeriez	Truth: pryeriez
# Prediction: levons	Truth: levons
# Prediction: recommandyez	Truth: recommandyez
# Prediction: courrouchent	Truth: courrouchent
# Prediction: eschauffoyent	Truth: eschauffoyent
# Prediction: desbauchoyent	Truth: desbauchoyent
# Prediction: fortiffiastes	Truth: fortiffiastes
# Prediction: presentoys	Truth: presentoys
# Prediction: enpoisonne	Truth: enpoisonne
# Prediction: representeront	Truth: representeront
# Prediction: pourchasse	Truth: pourchasse
# Prediction: precedois	Truth: precedions
# Prediction: escheviez	Truth: escheviez
# Prediction: deliberay	Truth: delibereray
# Prediction: regratiasse	Truth: regratiasse
# Prediction: enchargeryons	Truth: enchargeryons
# Prediction: nombroyt	Truth: nombroyt
# Prediction: enconcheras	Truth: enconcheras
# Prediction: iniurierai	Truth: iniurierai
# Prediction: expuysassions	Truth: expuysassions
# Prediction: presumast	Truth: presumast
# Prediction: trouverai	Truth: trouverai
# Prediction: possedes	Truth: possedes
# Prediction: hachoient	Truth: hachoient
# Prediction: trampa	Truth: trampa
# Prediction: enclinons	Truth: enclinons
# Prediction: quitte	Truth: quitte
# Prediction: enyvreroyt	Truth: enyvreroyt
# Prediction: foettera	Truth: foettera
# Prediction: bancqueter	Truth: bancqueter
# Prediction: desbordé	Truth: desbordé
# Prediction: finiroys	Truth: finiroys
# Prediction: hueriez	Truth: hueriez
# Prediction: logerons	Truth: logeons
# Prediction: appareilloyent	Truth: appareilloyent
# Prediction: contregardent	Truth: contregardent
# Prediction: chevauchieroys	Truth: chevauchieroys
# Prediction: accomplissiez	Truth: accomplissiez
# Prediction: destournez	Truth: destournez
# Prediction: precedois	Truth: precedois
# Prediction: embausmeront	Truth: embausmeront
# Prediction: racomptes	Truth: racomptes
# Prediction: galopoyent	Truth: galopoyent
# Prediction: enconches	Truth: enconches
# Prediction: quiegiois	Truth: veiglois
# Prediction: esveillera	Truth: esveillera
# Prediction: meritons	Truth: meritions
# Prediction: comptoys	Truth: comptoys
# Prediction: affermerent	Truth: affermerent
# Prediction: persuaderoient	Truth: persuaderoient
# Prediction: oultrageras	Truth: oultrageras
# Prediction: deliberyons	Truth: delibereryons
# Prediction: obligeasses	Truth: obligeasses
# Prediction: huchions	Truth: huchions
# Prediction: penentrent	Truth: penetrent
# Prediction: cerches	Truth: cerches
# Prediction: bancqueté	Truth: bancqueté
# Prediction: notoyent	Truth: notoyent
# Prediction: separerois	Truth: separerois
# Prediction: assistez	Truth: assistez
# Prediction: capoys	Truth: capyons
# Prediction: alosasse	Truth: alosasse
# Prediction: celois	Truth: celois
# Prediction: mulctez	Truth: mulctez
# Prediction: esclairant	Truth: esclairant
# Prediction: desguiser	Truth: desguiser
# Prediction: esmerveillasses	Truth: esmerveillasses
# Prediction: empoiquoyt	Truth: empoizonnoyt
# Prediction: redrechoyent	Truth: redrechoyent
# Prediction: estincelleray	Truth: estincelleray
# Prediction: remonsassions	Truth: remonstrassions
# Prediction: interpreteriez	Truth: interpreteriez
# Prediction: transporteroys	Truth: transporteroys
# Prediction: encontrast	Truth: encontrast
# Prediction: pourforcez	Truth: pourforcez
# Prediction: mehaignieront	Truth: mehaignieront
# Prediction: escielles	Truth: escielles
# Prediction: soingnoyent	Truth: soingnoyent
# Prediction: possedoyt	Truth: possedoyt
# Prediction: fromenteryez	Truth: fromenteryez
# Prediction: expellastes	Truth: expellastes
# Prediction: picquast	Truth: picquast
# Prediction: delaisseroys	Truth: delaisseroys
# Prediction: picquoit	Truth: picquoit
# Prediction: reculleray	Truth: reculleray
# Prediction: ottroyt	Truth: ottroyeroyt
# Prediction: rebarbera	Truth: rebarbera
# Prediction: impugne	Truth: impugne
# Prediction: acquitent	Truth: acquitent
# Prediction: fomentez	Truth: fomentez
# Prediction: tournerions	Truth: tournerions
# Prediction: ieusne	Truth: ieusne
# Prediction: deffiera	Truth: deffiera
# Prediction: gieillerois	Truth: veiglerois
# Prediction: penseront	Truth: penseront
# Prediction: iettons	Truth: iettons
# Prediction: lyoys	Truth: lyoys
# Prediction: gasté	Truth: gasté
# Prediction: approuvenderoys	Truth: approuvenderoys
# Prediction: desherityons	Truth: desherityons
# Prediction: presupposa	Truth: presupposa
# Prediction: chocquois	Truth: chocquois
# Prediction: monstrions	Truth: monstrions
# Prediction: cerchois	Truth: cerchois
# Prediction: impugnoys	Truth: impugnoys
# Prediction: desroboit	Truth: desroboit
# Prediction: avanchia	Truth: avancha
# Prediction: acceptasse	Truth: acceptasse
# Prediction: marchoys	Truth: marchoys
# Prediction: racointeroyt	Truth: racointeroyt
# Prediction: declairera	Truth: declairera
# Prediction: delaceryons	Truth: delaceryons
# Prediction: demoureroys	Truth: demoureroys
# Prediction: atournez	Truth: atournez
# Prediction: doubtasmes	Truth: doubtasmes
# Prediction: avallassions	Truth: avallassions
# Prediction: entrerouchant	Truth: en courouchant
# Prediction: estonnons	Truth: estonnons
# Prediction: rouilleront	Truth: rouilleront
# Prediction: tombois	Truth: tombois
# Prediction: advisons	Truth: advisons
# Prediction: alongeons	Truth: alongeons
# Prediction: cessons	Truth: cessons
# Prediction: rincerois	Truth: rincerois
# Prediction: resverez	Truth: resverez
# Prediction: tumberois	Truth: tumberois
# Prediction: navrerois	Truth: navrerois
# Prediction: parlons	Truth: parlons
# Prediction: fouller	Truth: fouller
# Prediction: goustant	Truth: goustant
# Prediction: transgloutioys	Truth: transgloutissoys
# Prediction: descourageas	Truth: descourageas
# Prediction: esparpilleront	Truth: esparpilleront
# Prediction: descouchieryons	Truth: descouchieryons
# Prediction: esquachoyent	Truth: esquachoyent
# Prediction: empiegiyez	Truth: empiegyez
# Prediction: deschargeras	Truth: deschargeras
# Prediction: participeryons	Truth: participeryons
# Prediction: empruntast	Truth: empruntast
# Prediction: escorches	Truth: escorches
# Prediction: regorgeassions	Truth: regorgeassions
# Prediction: embausmons	Truth: embausmons
# Prediction: acceptas	Truth: acceptas
# Prediction: inquiete	Truth: inquiete
# Prediction: regardastes	Truth: regardastes
# Prediction: alosois	Truth: alosois
# Prediction: moderasse	Truth: moderasse
# Prediction: recorderoys	Truth: recorderoys
# Prediction: chantez	Truth: chantez
# Prediction: alongeront	Truth: alongeront
# Prediction: couches	Truth: couches
# Prediction: luitte	Truth: luitte
# Prediction: nombrez	Truth: nombrez
# Prediction: ronfleroyent	Truth: ronfleroyent
# Prediction: deifieroyt	Truth: deifieroyt
# Prediction: iouasses	Truth: iouasses
# Prediction: bayseroys	Truth: bayseroys
# Prediction: salueroyt	Truth: salueroyt
# Prediction: frape	Truth: frape
# Prediction: houeroit	Truth: houeroit
# Prediction: eslever	Truth: eslever
# Prediction: nouer	Truth: nouer
# Prediction: deschevauchasmes	Truth: deschevauchasmes
# Prediction: enconvenesies	Truth: enconvenences
# Prediction: esmerveillassent	Truth: esmerveillassent
# Prediction: despossasmes	Truth: despossessasmes
# Prediction: manouvrois	Truth: manouvrois
# Prediction: depeschoit	Truth: depeschoit
# Prediction: aterminoys	Truth: aterminoys
# Prediction: estranglent	Truth: estranglent
# Prediction: travailleroys	Truth: travailleroys
# Prediction: protestasses	Truth: protestasses
# Prediction: scellois	Truth: scellois
# Prediction: soulaigera	Truth: soulaigera
# Prediction: separoient	Truth: separoient
# Prediction: tremblassions	Truth: tremblassions
# Prediction: goustasmes	Truth: goustasmes
# Prediction: arrivastes	Truth: arrivastes
# Prediction: gaignasse	Truth: gaignasse
# Prediction: esguare	Truth: esguare
# Prediction: habitast	Truth: habitast
# Prediction: rengeisiez	Truth: rengiez
# Prediction: touchassions	Truth: touchassions
# Prediction: ourita	Truth: quita
# Prediction: accusons	Truth: accusons
# Prediction: deifierons	Truth: deifierons
# Prediction: estires	Truth: estires
# Prediction: pisserions	Truth: pisserions
# Prediction: adaptez	Truth: adaptez
# Prediction: esguarpas	Truth: esguarant
# Prediction: gaberoit	Truth: gaberoit
# Prediction: entreparant	Truth: en preparant
# Prediction: tombé	Truth: tombé
# Prediction: emblant	Truth: emblant
# Prediction: raenchonnez	Truth: raenchonnez
# Prediction: rappelloyent	Truth: rappelloyent
# Prediction: esparpilles	Truth: esparpilles
# Prediction: provocquerai	Truth: provocquerai
# Prediction: desheriteront	Truth: desheriteront
# Prediction: accordoyt	Truth: accordoyt
# Prediction: revencherai	Truth: revencherai
# Prediction: desploieroit	Truth: desploieroit
# Prediction: esternuerez	Truth: esternuerez
# Prediction: desborderoient	Truth: desborderoient
# Prediction: esplucheront	Truth: esplucheront
# Prediction: laidengerez	Truth: laidengerez
# Prediction: honnoureroys	Truth: honnoureroys
# Prediction: hebergierions	Truth: hebergierions
# Prediction: praesideriez	Truth: praesideriez
# Prediction: empruntez	Truth: empruntez
# Prediction: esvanteroit	Truth: esvanteroit
# Prediction: executes	Truth: executes
# Prediction: respirez	Truth: respirez
# Prediction: couchastes	Truth: couchastes
# Prediction: atemptez	Truth: atemptez
# Prediction: desyrerions	Truth: desyrerions
# Prediction: gieilleras	Truth: veigleras
# Prediction: quitast	Truth: quitast
# Prediction: divineroys	Truth: divineroys
# Prediction: herrieroient	Truth: herrieroient
# Prediction: appellez	Truth: appellez
# Prediction: confesser	Truth: confesser
# Prediction: rotte	Truth: rotte
# Prediction: plie	Truth: plie
# Prediction: coustant	Truth: coustant
# Prediction: tiré	Truth: tiré
# Prediction: contrepoisoys	Truth: contrepoisoys
# Prediction: interpretoys	Truth: interpretoys
# Prediction: sontadassiez	Truth: vous entredesirassiez
# Prediction: soubhaittasse	Truth: soubhaittasse
# Prediction: nousez	Truth: vous entrehurtez
# Prediction: esgratigneront	Truth: esgratigneront
# Prediction: entredonneryons	Truth: entredonneryons
# Prediction: desregloyent	Truth: desregloyent
# Prediction: abhorroyt	Truth: abhorroyt
# Prediction: contribue	Truth: contribue
# Prediction: tournoyasse	Truth: tournoyasse
# Prediction: besoigna	Truth: besoigna
# Prediction: acoustreroit	Truth: acoustreroit
# Prediction: acoustreryez	Truth: acoustreryez
# Prediction: contregardant	Truth: contregardant
# Prediction: alongeisiez	Truth: alongiez
# Prediction: soumecteroient	Truth: soumectroient
# Prediction: penez	Truth: penetrez
# Prediction: alimente	Truth: alimente
# Prediction: gelloyt	Truth: gelloyt
# Prediction: raporteroient	Truth: raporteroient
# Prediction: derva	Truth: derva
# Prediction: regorgeons	Truth: regorgeons
# Prediction: dancrastes	Truth: dançastes
# Prediction: luitteront	Truth: luitteront
# Prediction: navrerai	Truth: navrerai
# Prediction: dampnent	Truth: dampnent
# Prediction: acquite	Truth: acquite
# Prediction: frapent	Truth: frapent
# Prediction: houe	Truth: houe
# Prediction: cryeras	Truth: cryeras
# Prediction: huerpez	Truth: huez
# Prediction: desprisonnoys	Truth: desprisonnoys
# Prediction: contrepoise	Truth: contrepoise
# Prediction: accompaignes	Truth: accompaignes
# Prediction: importunas	Truth: importunas
# Prediction: empruntois	Truth: empruntois
# Prediction: recuperassiez	Truth: recuperassiez
# Prediction: denunchieras	Truth: denunchieras
# Prediction: recuperasmes	Truth: recuperasmes
# Prediction: destachasse	Truth: destachasse
# Prediction: renommions	Truth: renommions
# Prediction: souspirastes	Truth: souspirastes
# Prediction: cointoions	Truth: cointoiassions
# Prediction: desplaces	Truth: desplaces
# Prediction: leichyez	Truth: leichyez
# Prediction: regorgeray	Truth: regorgeray
# Prediction: mulctois	Truth: mulctois
# Prediction: possesseroit	Truth: possesseroit
# Prediction: tranchez	Truth: tranchez
# Prediction: assistez	Truth: assistez
# Prediction: tabusteryez	Truth: tabusteryez
# Prediction: essayassiez	Truth: essayassiez
# Prediction: desnouera	Truth: desnouera
# Prediction: traittent	Truth: traittent
# Prediction: escarteriez	Truth: escarteriez
# Prediction: finoyent	Truth: finoyent
# Prediction: essayeroit	Truth: essayeroit
# Prediction: coucherois	Truth: coucherois
# Prediction: guident	Truth: guident
# Prediction: erigeons	Truth: erigeons
# Prediction: rottent	Truth: rottent
# Prediction: iolyeras	Truth: iolyeras
# Prediction: laisser	Truth: laisser
# Prediction: courrouche	Truth: courrouche
# Prediction: detranchasses	Truth: detranchasses
# Prediction: presupposassions	Truth: presupposassions
# Prediction: participerai	Truth: participerai
# Prediction: desadvouast	Truth: desadvouast
# Prediction: escorchois	Truth: escorchois
# Prediction: infourmast	Truth: infourmast
# Prediction: cherchois	Truth: cherchois
# Prediction: eschevyez	Truth: eschevyez
# Prediction: deifiyez	Truth: deifiyez
# Prediction: estoufferoyt	Truth: estoufferoyt
# Prediction: moustrastes	Truth: moustrastes
# Prediction: querelerai	Truth: querelerai
# Prediction: demande	Truth: demande
# Prediction: escumassiez	Truth: escumassiez
# Prediction: touchast	Truth: touchast
# Prediction: resignes	Truth: resignes
# Prediction: iolyoys	Truth: iolyoys
# Prediction: assiegeriez	Truth: assiegeriez
# Prediction: reigle	Truth: reigle
# Prediction: riffleryez	Truth: riffleryez
# Prediction: tempreroyt	Truth: tempreroyt
# Prediction: tyroit	Truth: tyroit
# Prediction: soucyez	Truth: soucyez
# Prediction: bayserois	Truth: bayserois
# Prediction: aorne	Truth: aorne
# Prediction: ronflons	Truth: ronflons
# Prediction: cachent	Truth: cachent
# Prediction: ralieryons	Truth: ralieryons
# Prediction: houasmes	Truth: houasmes
# Prediction: cessez	Truth: cessez
# Prediction: pechez	Truth: pechez
# Prediction: eschauffois	Truth: eschauffois
# Prediction: subiuguiois	Truth: subiuguois
# Prediction: representes	Truth: representes
# Prediction: estincelleroys	Truth: estincelleroys
# Prediction: esperonnas	Truth: esperonnas
# Prediction: hebergierent	Truth: hebergierent
# Prediction: escouillerois	Truth: escouillerois
# Prediction: escapperent	Truth: escapperent
# Prediction: bobeline	Truth: bobeline
# Prediction: accepta	Truth: accepta
# Prediction: croniquiez	Truth: croniquiez
# Prediction: trousserai	Truth: trousserai
# Prediction: offena	Truth: offença
# Prediction: ganglois	Truth: ganglois
# Prediction: achevoyt	Truth: achevoyt
# Prediction: possesse	Truth: possesse
# Prediction: separyez	Truth: separiez
# Prediction: soingnez	Truth: soingnez
# Prediction: menasse	Truth: menasse
# Prediction: enclineroys	Truth: enclineroys
# Prediction: reserveriez	Truth: reserveriez
# Prediction: impugnes	Truth: impugnes
# Prediction: escumast	Truth: escumast
# Prediction: humilieryons	Truth: humilieryons
# Prediction: operoient	Truth: operoient
# Prediction: trempe	Truth: trempe
# Prediction: soucyeroit	Truth: soucyeroit
# Prediction: chargera	Truth: chargera
# Prediction: fleschisse	Truth: fleschis
# Prediction: appuions	Truth: appuions
# Prediction: hachez	Truth: hachez
# Prediction: disné	Truth: disné
# Prediction: desadvouions	Truth: desadvouions
# Prediction: endommaigez	Truth: endommaigez
# Prediction: escielleray	Truth: escielleray
# Prediction: resistoyt	Truth: resistoyt
# Prediction: exploryons	Truth: explorions
# Prediction: presentast	Truth: presentast
# Prediction: bancqueteront	Truth: bancqueteront
# Prediction: espoventerez	Truth: espoventerez
# Prediction: advanquois	Truth: advançois
# Prediction: prospereroys	Truth: prospereroys
# Prediction: fomentas	Truth: fomentas
# Prediction: esguiserai	Truth: esguiserai
# Prediction: tournoye	Truth: tournoye
# Prediction: desploies	Truth: desploies
# Prediction: evaporerent	Truth: evaporerent
# Prediction: seiournes	Truth: seiournes
# Prediction: tempra	Truth: tempra
# Prediction: protegera	Truth: protegera
# Prediction: accusa	Truth: accusa
# Prediction: desarmez	Truth: desarmez
# Prediction: atemptera	Truth: atemptera
# Prediction: enterreryez	Truth: enterreryez
# Prediction: menasseroient	Truth: menasseroient
# Prediction: pacquasse	Truth: pacquasse
# Prediction: aracheroient	Truth: aracheroient
# Prediction: pillast	Truth: pillast
# Prediction: adviseroit	Truth: adviseroit
# Prediction: poisons	Truth: poisons
# Prediction: cryent	Truth: cryent
# Prediction: pryeryons	Truth: pryeryons
# Prediction: leschant	Truth: leschant
# Prediction: tireons	Truth: tirons
# Prediction: desprisonnastes	Truth: desprisonnastes
# Prediction: recommandoyt	Truth: recommandoyt
# Prediction: enseignyez	Truth: enseignyez
# Prediction: esperonnyez	Truth: esperonnyez
# Prediction: croniquioys	Truth: croniquioys
# Prediction: rasseura	Truth: r'asseura
# Prediction: remercyoys	Truth: remercyoys
# Prediction: accordoys	Truth: accordoys
# Prediction: assiegeoys	Truth: assiegeoys
# Prediction: rebarbois	Truth: rebarbois
# Prediction: desadvouerions	Truth: desadvouerions
# Prediction: merveillierons	Truth: merveillerons
# Prediction: estrangleroit	Truth: estrangleroit
# Prediction: empiegeoyent	Truth: empiegeoyent
# Prediction: humilia	Truth: humilia
# Prediction: estachasses	Truth: estachasses
# Prediction: oultrage	Truth: oultrage
# Prediction: souspireroient	Truth: souspireroient
# Prediction: laidengerons	Truth: laidengerons
# Prediction: atempterent	Truth: atempterent
# Prediction: prosperont	Truth: prospereront
# Prediction: advanceras	Truth: advança
# Prediction: marchyez	Truth: marchyez
# Prediction: estimerent	Truth: estimerent
# Prediction: heurteray	Truth: heurteray
# Prediction: blessent	Truth: blessent
# Prediction: pensassions	Truth: pensassions
# Prediction: abiurerez	Truth: abiurerez
# Prediction: aloseroient	Truth: aloseroient
# Prediction: finez	Truth: finez
# Prediction: soupper	Truth: soupper
# Prediction: invité	Truth: invité
# Prediction: houssepilloient	Truth: houssepilloient
# Prediction: courrouchoyent	Truth: courrouçoyent
# Prediction: contribuoient	Truth: contribuoient
# Prediction: participassions	Truth: participassions
# Prediction: transportes	Truth: transportes
# Prediction: rappellerent	Truth: rappellerent
# Prediction: courrouceras	Truth: courrouceras
# Prediction: denunchent	Truth: denunchient
# Prediction: subiectassions	Truth: subiectassions
# Prediction: recullois	Truth: recullois
# Prediction: remonstre	Truth: remonstre
# Prediction: proclama	Truth: proclama
# Prediction: ymaginions	Truth: ymaginions
# Prediction: retournasse	Truth: retournasse
# Prediction: racomptast	Truth: racomptast
# Prediction: desploiassiez	Truth: desploiassiez
# Prediction: embausmerois	Truth: embausmerois
# Prediction: escouille	Truth: escouille
# Prediction: moderois	Truth: moderois
# Prediction: esprouveras	Truth: esprouveras
# Prediction: delivras	Truth: delivras
# Prediction: baysoit	Truth: baysoit
# Prediction: enhorterions	Truth: enhorterions
# Prediction: advances	Truth: advances
# Prediction: regorges	Truth: regorges
# Prediction: penetrez	Truth: penetrez
# Prediction: escryez	Truth: escryons
# Prediction: appuierez	Truth: appuierez
# Prediction: seellera	Truth: seellera
# Prediction: robbent	Truth: robbent
# Prediction: haittant	Truth: haittant
# Prediction: enerravant	Truth: en reverant
# Prediction: enconvenenioient	Truth: enconvenençoient
# Prediction: esmerveille	Truth: esmerveille
# Prediction: contrepoisez	Truth: contrepoisez
# Prediction: transgloutiroyt	Truth: transgloutiroyt
# Prediction: condescendrient	Truth: condescendreient
# Prediction: desmettois	Truth: desmettois
# Prediction: possons	Truth: possessois
# Prediction: gouvernasmes	Truth: gouvernasmes
# Prediction: seiournasses	Truth: seiournasses
# Prediction: empruntassiez	Truth: empruntassiez
# Prediction: racompteray	Truth: racompteray
# Prediction: emergyez	Truth: emergyez
# Prediction: picquois	Truth: picquois
# Prediction: nettoyassent	Truth: nettoyassent
# Prediction: tournoyez	Truth: tournoyez
# Prediction: see	Truth: seelloit
# Prediction: prosperez	Truth: prosperez
# Prediction: chantassent	Truth: chantassent
# Prediction: resignent	Truth: resignent
# Prediction: ordonneroyent	Truth: ordonneroyent
# Prediction: essilons	Truth: essilions
# Prediction: frapions	Truth: frapyons
# Prediction: empira	Truth: empira
# Prediction: estacheryons	Truth: estacheryons
# Prediction: resvasmes	Truth: resvasmes
# Prediction: mucoit	Truth: muçoit
# Prediction: brusle	Truth: brusle
# Prediction: resumerions	Truth: resumerions
# Prediction: guarderois	Truth: guarderois
# Prediction: moderons	Truth: moderons
# Prediction: iettasses	Truth: iettasses
# Prediction: ieunez	Truth: ieunez
# Prediction: communicichions	Truth: communicquyons
# Prediction: estouffaions	Truth: estouffions
# Prediction: estourdissoyent	Truth: estourdissoyent
# Prediction: espargeoyt	Truth: espargnoyt
# Prediction: praesent	Truth: praesentons
# Prediction: celebroyt	Truth: celebroyt
# Prediction: destable	Truth: destable
# Prediction: participe	Truth: participe
# Prediction: retourneroys	Truth: retourneroys
# Prediction: regarderoys	Truth: regarderoys
# Prediction: traitte	Truth: traitte
# Prediction: eschappez	Truth: eschappez
# Prediction: marcha	Truth: marcha
# Prediction: esguisez	Truth: esguisez
# Prediction: expuysons	Truth: expuysons
# Prediction: evaporera	Truth: evaporera
# Prediction: negotieroys	Truth: negotieroys
# Prediction: esmayassiez	Truth: esmayassiez
# Prediction: impugneroyent	Truth: impugneroyent
# Prediction: estonnons	Truth: estonnons
# Prediction: serainent	Truth: serainent
# Prediction: escarte	Truth: escarte
# Prediction: qollassions	Truth: vollassions
# Prediction: esleverions	Truth: esleverions
# Prediction: guida	Truth: guida
# Prediction: touchez	Truth: touchez
# Prediction: guerpinent	Truth: guerpissent
# Prediction: marieroient	Truth: marieroient
# Prediction: opererois	Truth: opererois
# Prediction: lyerai	Truth: lyerai
# Prediction: tire	Truth: tire
# Prediction: pensé	Truth: pensé
# Prediction: adioustoient	Truth: adioustoient
# Prediction: empeschois	Truth: empeschois
# Prediction: blasphequez	Truth: blasphemez
# Prediction: desgorgerai	Truth: desgorgerai
# Prediction: retournastes	Truth: retournastes
# Prediction: cerchyez	Truth: cerchyez
# Prediction: pourforceront	Truth: pourforceront
# Prediction: estudioyent	Truth: estudioyent
# Prediction: desnouoit	Truth: desnouoit
# Prediction: prospera	Truth: prospera
# Prediction: escorcha	Truth: escorcha
# Prediction: persuadasse	Truth: persuadasse
# Prediction: invitoient	Truth: invitoient
# Prediction: arrengiera	Truth: arrengiera
# Prediction: monstrastes	Truth: monstrastes
# Prediction: gielioys	Truth: veigloys
# Prediction: surnommeroit	Truth: surnommeroit
# Prediction: desrisieroyent	Truth: desrisieroyent
# Prediction: cerchoit	Truth: cerchoit
# Prediction: nettoyas	Truth: nettoyas
# Prediction: enconcheriez	Truth: enconcheriez
# Prediction: assiegent	Truth: assiegeons
# Prediction: estudierois	Truth: estudierois
# Prediction: estiquiez	Truth: estiquiez
# Prediction: couches	Truth: couches
# Prediction: reiettons	Truth: reiettons
# Prediction: urines	Truth: urines
# Prediction: robbera	Truth: robbera
# Prediction: emblerons	Truth: emblerons
# Prediction: abosché	Truth: abosché
# Prediction: gaigné	Truth: gaigné
# Prediction: ostant	Truth: en ostant
# Prediction: courrouchiez	Truth: courrouchiez
# Prediction: representerons	Truth: representerons
# Prediction: desprisonnez	Truth: desprisonnez
# Prediction: empruntoyt	Truth: empruntoyt
# Prediction: destabloys	Truth: destabloys
# Prediction: esbauchastes	Truth: esbauchastes
# Prediction: esternuasses	Truth: esternuasses
# Prediction: deschargerois	Truth: deschargerois
# Prediction: recuperasses	Truth: recuperasses
# Prediction: atournois	Truth: atournois
# Prediction: besoignerez	Truth: besoignerez
# Prediction: gaspilleras	Truth: gaspilleras
# Prediction: seiournera	Truth: seiournera
# Prediction: desgorgez	Truth: desgorgez
# Prediction: empruntez	Truth: empruntez
# Prediction: leichassions	Truth: leichassions
# Prediction: mariois	Truth: mariois
# Prediction: abhorre	Truth: abhorre
# Prediction: impugneroit	Truth: impugneroit
# Prediction: ottroyera	Truth: ottroyera
# Prediction: obligeastes	Truth: obligeastes
# Prediction: resvoyent	Truth: resvoyent
# Prediction: amadouez	Truth: amadouez
# Prediction: picqueryez	Truth: picqueryez
# Prediction: esguise	Truth: esguise
# Prediction: esgalerois	Truth: esgalerois
# Prediction: estoit	Truth: estoit
# Prediction: cryeray	Truth: cryeray
# Prediction: pretera	Truth: pretera
# Prediction: louez	Truth: louez
# Prediction: prions	Truth: prions
# Prediction: lye	Truth: lye
# Prediction: couchois	Truth: couchois
# Prediction: desplacez	Truth: desplacez
# Prediction: assiegerent	Truth: assiegerent
# Prediction: picquieront	Truth: picquieront
# Prediction: rouillerons	Truth: rouillerons
# Prediction: iolyasse	Truth: iolyasse
# Prediction: confessant	Truth: confessant
# Prediction: foullant	Truth: foullant
